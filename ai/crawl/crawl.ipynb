# %% [markdown]
# # **Crawl.ipynb: Notebook for ingesting and crawling data from multiple sources**
# **Author**: Khang P. Nguyen
# **Date**: May 20, 2026
#
# In this notebook, I implement an end-to-end pipeline for ingesting, downloading and crawling data from mutiple sources like website **Cục di sản văn hóa**, **UNESCO**, .etc.

# %% [markdown]
# ## **1. Cục di sản văn hóa Website**

# %%
# !python -m pip install -U pip setuptools wheel
# !python -m pip install crawl4ai
# Out:
# ...
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 81.0.0
#     Uninstalling setuptools-81.0.0:
#       Successfully uninstalled setuptools-81.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.12.0 requires setuptools<82, but you have setuptools 82.0.1 which is incompatible.
# ...
#   Using cached openai-2.37.0-py3-none-any.whl.metadata (31 kB)
# ...
# Using cached openai-2.37.0-py3-none-any.whl (1.3 MB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
# ...

# %%
import asyncio
from crawl4ai import *

async def main():
    async with AsyncWebCrawler() as crawler:
        result = await crawler.arun(
            url="https://dsvh.gov.vn/",
        )
        print(result.markdown)
await main()
# Out:
# [INIT].... → Crawl4AI 0.8.6
# [FETCH]... ↓ https://dsvh.gov.vn/                                                                                 |
# ✓ | ⏱: 2.43s
# [SCRAPE].. ◆ https://dsvh.gov.vn/                                                                                 |
# ✓ | ⏱: 0.10s
# [COMPLETE] ● https://dsvh.gov.vn/                                                                                 |
# ✓ | ⏱: 2.55s
#   * [Trang chủ](https://dsvh.gov.vn/)
#   * [Giới thiệu](https://dsvh.gov.vn/gioi-thieu-15%09)
#     * [Thông tin chung](https://dsvh.gov.vn/thong-tin-chung-1727)
#     * [Cơ cấu tổ chức](https://dsvh.gov.vn/co-cau-to-chuc-1745)
#     * [Các tổ chức tư vấn liên quan](https://dsvh.gov.vn/cac-to-chuc-tu-van-lien-quan-1743)
#   * [Tin tức - sự kiện](https://dsvh.gov.vn/tin-tuc-su-kien-3)
#   * [THÔNG TIN DI SẢN VĂN HÓA ](https://dsvh.gov.vn/thong-tin-di-san-van-hoa-121)
#     * [Di tích ](https://dsvh.gov.vn/di-tich-1746)
# ...

# %%
# !python -m pip install marker-pdf streamlit streamlit-ace
# Out:
# ...
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1 0/2 [setuptools]
#   Attempting uninstall: openai━━━━━━━━━━━━━━━━━━ 0/2 [setuptools]
#     Found existing installation: openai 2.37.00m 0/2 [setuptools]
#     Uninstalling openai-2.37.0:m╺━━━━━━━━━━━━━━━━━━━ 1/2 [openai]
#       Successfully uninstalled openai-2.37.0━━━━━━━━━━━━━━━━━━ 1/2 [openai]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openai]2m1/2 [openai]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...
